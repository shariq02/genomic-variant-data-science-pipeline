# %% [markdown]
# # Disease ML Features - Exploratory Data Analysis
# **DNA Gene Mapping Project - ML Phase V5**
# **Author:** Sharique Mohammad
# **Date:** February 2026
# **Table:** disease_ml_features (4.1M variants, 64 columns)
#
# ## Objective
# Deep exploration of disease associations, complexity patterns, and clinical features.
#
# ## Key Questions
# 1. What is the distribution of pathogenic, benign, and VUS variants?
# 2. How are diseases annotated across OMIM, MONDO, and Orphanet databases?
# 3. What is the disease complexity landscape (monogenic vs polygenic)?
# 4. Which genes have the highest disease associations?
# 5. What features correlate most with pathogenicity?
#
# ## Deliverables
# - 12+ visualizations saved to disease_ml_features/images/
# - EDA report saved to disease_ml_features/reports/
# - Missing values CSV saved to disease_ml_features/metrics/
# - Correlation matrix CSV saved to disease_ml_features/metrics/
# - Feature statistics CSV saved to disease_ml_features/metrics/

# %% [markdown]
# ## 1. Setup and Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine
import os
from pathlib import Path
from dotenv import load_dotenv
import warnings
warnings.filterwarnings('ignore')

load_dotenv()

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 10

PROJECT_ROOT = Path().absolute().parent.parent
BASE_OUT     = PROJECT_ROOT / 'data' / 'analytical' / 'disease_ml_features'
IMAGES_DIR   = BASE_OUT / 'images'
REPORTS_DIR  = BASE_OUT / 'reports'
METRICS_DIR  = BASE_OUT / 'metrics'

IMAGES_DIR.mkdir(parents=True, exist_ok=True)
REPORTS_DIR.mkdir(parents=True, exist_ok=True)
METRICS_DIR.mkdir(parents=True, exist_ok=True)

print("Setup complete")
print(f"Images  : {IMAGES_DIR}")
print(f"Reports : {REPORTS_DIR}")
print(f"Metrics : {METRICS_DIR}")

# %% [markdown]
# ## 2. Database Connection

# %%
POSTGRES_HOST     = os.getenv("POSTGRES_HOST")
POSTGRES_PORT     = os.getenv("POSTGRES_PORT")
POSTGRES_DB       = os.getenv("POSTGRES_DB")
POSTGRES_USER     = os.getenv("POSTGRES_USER")
POSTGRES_PASSWORD = os.getenv("POSTGRES_PASSWORD")

conn_str = f"postgresql://{POSTGRES_USER}:{POSTGRES_PASSWORD}@{POSTGRES_HOST}:{POSTGRES_PORT}/{POSTGRES_DB}"
engine = create_engine(conn_str)

print("Database connection established")
print(f"Host : {POSTGRES_HOST}:{POSTGRES_PORT}")
print(f"DB   : {POSTGRES_DB}")

# %% [markdown]
# ## 3. Data Loading

# %%
print("Loading disease_ml_features (10% sample)...")
query = """
    SELECT * FROM gold.disease_ml_features
    TABLESAMPLE SYSTEM (10)
"""
df = pd.read_sql(query, engine)

print(f"Rows loaded    : {len(df):,}")
print(f"Columns        : {len(df.columns)}")
print(f"Memory usage   : {df.memory_usage(deep=True).sum() / 1024**2:.1f} MB")
print(f"Full table est : ~4.1M rows")

# %% [markdown]
# ## 4. Type Conversion

# %%
# Gold schema types for disease_ml_features
# INT columns
int_cols = [
    'disease_db_coverage', 'disease_count', 'omim_disease_count',
    'disease_association_strength', 'disease_total_variants',
    'disease_pathogenic_variants', 'disease_benign_variants', 'disease_vus_variants',
    'disease_gene_count', 'disease_complexity_score', 'gene_total_variants',
    'gene_pathogenic_count', 'gene_benign_count', 'gene_high_quality_count',
    'gene_disease_diversity', 'gene_clinical_utility_score', 'gene_annotation_score',
    'gene_omim_variants', 'gene_mondo_variants', 'gene_well_annotated_variants',
    'tissues_expressed_count', 'cancer_mutation_count', 'gene_domain_count'
]

# DOUBLE columns
double_cols = ['disease_pathogenic_ratio', 'phylop_score', 'cadd_phred']

# BOOLEAN columns
bool_cols = [
    'is_pathogenic', 'is_benign', 'is_vus',
    'has_omim_disease', 'has_mondo_disease', 'has_orphanet_disease',
    'disease_is_well_annotated', 'disease_name_is_generic',
    'is_disease_associated', 'is_multi_disease_gene', 'is_omim_gene',
    'is_polygenic_disease', 'disease_has_high_pathogenic_burden',
    'is_clinically_actionable', 'is_research_candidate',
    'has_excellent_annotation', 'is_broadly_expressed',
    'is_cancer_hotspot_gene', 'is_highly_conserved',
    'has_high_conservation', 'is_complex_protein'
]

for col in int_cols:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce').astype('Int64')

for col in double_cols:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce')

for col in bool_cols:
    if col in df.columns:
        df[col] = df[col].astype(str).str.lower().map({'true': True, 'false': False})

print("Type conversion complete")
print(df.dtypes.value_counts())

# %% [markdown]
# ## 5. Dataset Overview

# %%
print("Dataset Overview")
print("=" * 60)
print(f"Total variants  : {len(df):,}")
print(f"Total columns   : {len(df.columns)}")
print(f"Unique genes    : {df['gene_name'].nunique():,}")
print(f"Chromosomes     : {df['chromosome'].nunique()}")
print()
print("Column list:")
for i, col in enumerate(df.columns, 1):
    print(f"  {i:2d}. {col:<45} {str(df[col].dtype)}")

# %% [markdown]
# ## 6. Missing Values Analysis

# %%
missing = pd.DataFrame({
    'column': df.columns,
    'missing_count': df.isnull().sum().values,
    'missing_pct': (df.isnull().sum().values / len(df) * 100).round(2)
}).sort_values('missing_pct', ascending=False)

missing_with_nulls = missing[missing['missing_count'] > 0]
print(f"Columns with missing values: {len(missing_with_nulls)}")
print()
print(missing_with_nulls.to_string(index=False))

missing.to_csv(METRICS_DIR / 'missing_values.csv', index=False)
print(f"\nSaved: {METRICS_DIR / 'missing_values.csv'}")

# %% [markdown]
# ## 7. Target Variable Analysis

# %%
total = len(df)

pathogenic_count = df['is_pathogenic'].sum() if 'is_pathogenic' in df.columns else 0
benign_count     = df['is_benign'].sum()     if 'is_benign'     in df.columns else 0
vus_count        = df['is_vus'].sum()        if 'is_vus'        in df.columns else 0

print("Clinical Significance Distribution")
print("=" * 50)
print(f"Pathogenic : {pathogenic_count:>10,}  ({pathogenic_count/total*100:>5.1f}%)")
print(f"Benign     : {benign_count:>10,}  ({benign_count/total*100:>5.1f}%)")
print(f"VUS        : {vus_count:>10,}  ({vus_count/total*100:>5.1f}%)")

if pathogenic_count > 0 and benign_count > 0:
    imbalance_ratio = max(pathogenic_count, benign_count) / min(pathogenic_count, benign_count)
    print(f"\nClass imbalance ratio : {imbalance_ratio:.2f}:1")
    smote_needed = imbalance_ratio > 5
    print(f"SMOTE needed          : {smote_needed}")

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

categories = ['Pathogenic', 'Benign', 'VUS']
counts     = [pathogenic_count, benign_count, vus_count]
colors     = ['#e74c3c', '#27ae60', '#95a5a6']

bars = axes[0].bar(categories, counts, color=colors, alpha=0.8, edgecolor='black')
for bar, count in zip(bars, counts):
    axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height(),
                 f'{count:,}\n({count/total*100:.1f}%)',
                 ha='center', va='bottom', fontsize=10, fontweight='bold')
axes[0].set_ylabel('Number of Variants', fontsize=11, fontweight='bold')
axes[0].set_title('Clinical Significance Distribution', fontsize=12, fontweight='bold')
axes[0].grid(axis='y', alpha=0.3)

if 'clinical_significance_simple' in df.columns:
    sig_dist = df['clinical_significance_simple'].value_counts().head(8)
    sig_dist.plot(kind='barh', ax=axes[1], color='steelblue', alpha=0.8, edgecolor='black')
    axes[1].set_xlabel('Count', fontsize=11, fontweight='bold')
    axes[1].set_title('Clinical Significance Categories', fontsize=12, fontweight='bold')
    axes[1].grid(axis='x', alpha=0.3)

plt.tight_layout()
plt.savefig(IMAGES_DIR / '01_clinical_significance.png', dpi=150, bbox_inches='tight')
plt.show()
print(f"Saved: 01_clinical_significance.png")

# %% [markdown]
# ## 8. Disease Database Coverage

# %%
omim_cov     = df['has_omim_disease'].sum()     if 'has_omim_disease'     in df.columns else 0
mondo_cov    = df['has_mondo_disease'].sum()    if 'has_mondo_disease'    in df.columns else 0
orphanet_cov = df['has_orphanet_disease'].sum() if 'has_orphanet_disease' in df.columns else 0

print("Disease Database Coverage")
print("=" * 50)
print(f"OMIM     : {omim_cov:>10,}  ({omim_cov/total*100:>5.1f}%)")
print(f"MONDO    : {mondo_cov:>10,}  ({mondo_cov/total*100:>5.1f}%)")
print(f"Orphanet : {orphanet_cov:>10,}  ({orphanet_cov/total*100:>5.1f}%)")

all_three = (
    (df['has_omim_disease'] == True) &
    (df['has_mondo_disease'] == True) &
    (df['has_orphanet_disease'] == True)
).sum()

omim_only = (
    (df['has_omim_disease'] == True) &
    (df['has_mondo_disease'] == False) &
    (df['has_orphanet_disease'] == False)
).sum()

print(f"\nAll three DBs : {all_three:,}")
print(f"OMIM only     : {omim_only:,}")

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

databases = ['OMIM', 'MONDO', 'Orphanet']
cov_vals  = [omim_cov, mondo_cov, orphanet_cov]
colors    = ['#e74c3c', '#3498db', '#2ecc71']

bars = axes[0].bar(databases, cov_vals, color=colors, alpha=0.8, edgecolor='black')
for bar, count in zip(bars, cov_vals):
    axes[0].text(bar.get_x() + bar.get_width()/2., bar.get_height(),
                 f'{count:,}\n({count/total*100:.1f}%)',
                 ha='center', va='bottom', fontsize=10, fontweight='bold')
axes[0].set_ylabel('Number of Variants', fontsize=11, fontweight='bold')
axes[0].set_title('Disease Database Coverage', fontsize=12, fontweight='bold')
axes[0].grid(axis='y', alpha=0.3)

if 'disease_db_coverage' in df.columns:
    cov_dist = df['disease_db_coverage'].value_counts().sort_index()
    axes[1].bar(cov_dist.index.astype(str), cov_dist.values,
                color='mediumpurple', alpha=0.8, edgecolor='black')
    axes[1].set_xlabel('Number of Databases with Coverage', fontsize=11, fontweight='bold')
    axes[1].set_ylabel('Number of Variants', fontsize=11, fontweight='bold')
    axes[1].set_title('Database Coverage Score Distribution', fontsize=12, fontweight='bold')
    axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(IMAGES_DIR / '02_database_coverage.png', dpi=150, bbox_inches='tight')
plt.show()
print(f"Saved: 02_database_coverage.png")

# %% [markdown]
# ## 9. Disease Complexity and Polygenic Risk

# %%
if 'disease_complexity' in df.columns:
    print("Disease Complexity Distribution")
    print("=" * 50)
    complexity_dist = df['disease_complexity'].value_counts()
    print(complexity_dist.to_string())
    
    fig, axes = plt.subplots(1, 2, figsize=(14, 6))
    
    complexity_dist.plot(kind='bar', ax=axes[0], color='coral', alpha=0.8, edgecolor='black')
    axes[0].set_xlabel('Complexity Category', fontsize=11, fontweight='bold')
    axes[0].set_ylabel('Number of Variants', fontsize=11, fontweight='bold')
    axes[0].set_title('Disease Complexity Distribution', fontsize=12, fontweight='bold')
    axes[0].tick_params(axis='x', rotation=45)
    axes[0].grid(axis='y', alpha=0.3)
    
    if 'disease_gene_count' in df.columns:
        axes[1].hist(df['disease_gene_count'].dropna(), bins=40,
                     color='coral', alpha=0.8, edgecolor='black')
        axes[1].set_xlabel('Number of Genes per Disease', fontsize=11, fontweight='bold')
        axes[1].set_ylabel('Frequency', fontsize=11, fontweight='bold')
        axes[1].set_title('Disease Gene Count Distribution', fontsize=12, fontweight='bold')
        axes[1].grid(alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(IMAGES_DIR / '03_disease_complexity.png', dpi=150, bbox_inches='tight')
    plt.show()
    print(f"Saved: 03_disease_complexity.png")

# %%
if 'polygenic_risk_contribution' in df.columns:
    print("Polygenic Risk Contribution Distribution")
    prc_dist = df['polygenic_risk_contribution'].value_counts()
    print(prc_dist.to_string())
    
    fig, ax = plt.subplots(figsize=(10, 6))
    prc_dist.plot(kind='bar', ax=ax, color='teal', alpha=0.8, edgecolor='black')
    ax.set_xlabel('Polygenic Risk Contribution', fontsize=11, fontweight='bold')
    ax.set_ylabel('Number of Variants', fontsize=11, fontweight='bold')
    ax.set_title('Polygenic Risk Contribution Distribution', fontsize=12, fontweight='bold')
    ax.tick_params(axis='x', rotation=45)
    ax.grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(IMAGES_DIR / '04_polygenic_risk.png', dpi=150, bbox_inches='tight')
    plt.show()
    print(f"Saved: 04_polygenic_risk.png")

# %% [markdown]
# ## 10. Gene-Level Disease Features

# %%
if 'gene_name' in df.columns and 'gene_disease_diversity' in df.columns:
    top_genes = (df.groupby('gene_name')['gene_disease_diversity']
                   .first()
                   .sort_values(ascending=False)
                   .head(20))
    
    print("Top 20 Genes by Disease Diversity")
    print(top_genes.to_string())
    
    fig, ax = plt.subplots(figsize=(12, 8))
    top_genes.sort_values().plot(kind='barh', ax=ax, color='steelblue', alpha=0.8, edgecolor='black')
    ax.set_xlabel('Disease Diversity Score', fontsize=11, fontweight='bold')
    ax.set_ylabel('Gene', fontsize=11, fontweight='bold')
    ax.set_title('Top 20 Genes by Disease Diversity', fontsize=12, fontweight='bold')
    ax.grid(axis='x', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(IMAGES_DIR / '05_top_genes_disease_diversity.png', dpi=150, bbox_inches='tight')
    plt.show()
    print(f"Saved: 05_top_genes_disease_diversity.png")

# %%
if 'gene_priority_tier' in df.columns:
    print("Gene Priority Tier Distribution")
    tier_dist = df['gene_priority_tier'].value_counts()
    print(tier_dist.to_string())
    
    fig, axes = plt.subplots(1, 2, figsize=(14, 6))
    
    tier_dist.plot(kind='bar', ax=axes[0], color='mediumpurple', alpha=0.8, edgecolor='black')
    axes[0].set_xlabel('Priority Tier', fontsize=11, fontweight='bold')
    axes[0].set_ylabel('Number of Variants', fontsize=11, fontweight='bold')
    axes[0].set_title('Gene Priority Tier Distribution', fontsize=12, fontweight='bold')
    axes[0].tick_params(axis='x', rotation=45)
    axes[0].grid(axis='y', alpha=0.3)
    
    if 'gene_clinical_utility_score' in df.columns:
        axes[1].hist(df['gene_clinical_utility_score'].dropna(), bins=30,
                     color='mediumpurple', alpha=0.8, edgecolor='black')
        axes[1].set_xlabel('Clinical Utility Score', fontsize=11, fontweight='bold')
        axes[1].set_ylabel('Frequency', fontsize=11, fontweight='bold')
        axes[1].set_title('Gene Clinical Utility Score Distribution', fontsize=12, fontweight='bold')
        axes[1].grid(alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(IMAGES_DIR / '06_gene_priority.png', dpi=150, bbox_inches='tight')
    plt.show()
    print(f"Saved: 06_gene_priority.png")

# %% [markdown]
# ## 11. Numeric Feature Distributions

# %%
key_numeric = [
    'disease_count', 'omim_disease_count', 'disease_association_strength',
    'disease_total_variants', 'disease_pathogenic_variants',
    'disease_complexity_score', 'disease_gene_count',
    'gene_total_variants', 'gene_pathogenic_count',
    'gene_clinical_utility_score', 'gene_disease_diversity',
    'gene_annotation_score', 'tissues_expressed_count',
    'cancer_mutation_count', 'gene_domain_count',
    'phylop_score', 'cadd_phred', 'disease_pathogenic_ratio'
]

key_numeric = [c for c in key_numeric if c in df.columns]
print(f"Numeric features to plot: {len(key_numeric)}")

n_cols = 3
n_rows = (len(key_numeric) + n_cols - 1) // n_cols

fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, n_rows * 4))
axes = axes.flatten()

for i, col in enumerate(key_numeric):
    data = df[col].dropna()
    axes[i].hist(data, bins=40, color='skyblue', alpha=0.8, edgecolor='black')
    axes[i].set_title(col, fontsize=10, fontweight='bold')
    axes[i].set_xlabel('Value', fontsize=9)
    axes[i].set_ylabel('Frequency', fontsize=9)
    axes[i].grid(alpha=0.3)
    median_val = data.median()
    axes[i].axvline(median_val, color='red', linestyle='--', linewidth=1.5,
                    label=f'Median: {median_val:.1f}')
    axes[i].legend(fontsize=8)

for i in range(len(key_numeric), len(axes)):
    axes[i].axis('off')

plt.tight_layout()
plt.savefig(IMAGES_DIR / '07_numeric_distributions.png', dpi=150, bbox_inches='tight')
plt.show()
print(f"Saved: 07_numeric_distributions.png")

# %% [markdown]
# ## 12. Boolean Feature Analysis

# %%
bool_features = [
    'is_pathogenic', 'is_benign', 'is_vus',
    'has_omim_disease', 'has_mondo_disease', 'has_orphanet_disease',
    'disease_is_well_annotated', 'is_disease_associated',
    'is_multi_disease_gene', 'is_omim_gene', 'is_polygenic_disease',
    'disease_has_high_pathogenic_burden', 'is_clinically_actionable',
    'is_research_candidate', 'has_excellent_annotation',
    'is_broadly_expressed', 'is_cancer_hotspot_gene',
    'is_highly_conserved', 'has_high_conservation', 'is_complex_protein'
]

bool_features = [c for c in bool_features if c in df.columns]

bool_rates = {}
for col in bool_features:
    bool_rates[col] = df[col].sum() / total * 100

bool_df = pd.Series(bool_rates).sort_values(ascending=True)

fig, ax = plt.subplots(figsize=(12, 10))
colors = ['#e74c3c' if v > 50 else '#3498db' for v in bool_df.values]
bars = ax.barh(bool_df.index, bool_df.values, color=colors, alpha=0.8, edgecolor='black')

for bar, val in zip(bars, bool_df.values):
    ax.text(bar.get_width() + 0.5, bar.get_y() + bar.get_height()/2.,
            f'{val:.1f}%', va='center', fontsize=9, fontweight='bold')

ax.set_xlabel('Percentage of Variants (%)', fontsize=11, fontweight='bold')
ax.set_title('Boolean Feature True Rates', fontsize=12, fontweight='bold')
ax.set_xlim(0, 110)
ax.grid(axis='x', alpha=0.3)

plt.tight_layout()
plt.savefig(IMAGES_DIR / '08_boolean_features.png', dpi=150, bbox_inches='tight')
plt.show()
print(f"Saved: 08_boolean_features.png")

print("\nBoolean feature summary:")
for col, rate in sorted(bool_rates.items(), key=lambda x: -x[1]):
    print(f"  {col:<45} {rate:>5.1f}%")

# %% [markdown]
# ## 13. Correlation Analysis

# %%
corr_features = [
    'disease_count', 'omim_disease_count', 'disease_association_strength',
    'disease_total_variants', 'disease_pathogenic_variants',
    'disease_complexity_score', 'gene_total_variants',
    'gene_pathogenic_count', 'gene_clinical_utility_score',
    'gene_disease_diversity', 'gene_annotation_score',
    'tissues_expressed_count', 'cancer_mutation_count',
    'phylop_score', 'cadd_phred', 'disease_pathogenic_ratio'
]

corr_features = [c for c in corr_features if c in df.columns]
corr_data     = df[corr_features].apply(pd.to_numeric, errors='coerce')
corr_matrix   = corr_data.corr()

corr_matrix.to_csv(METRICS_DIR / 'correlation_matrix.csv')
print(f"Saved: {METRICS_DIR / 'correlation_matrix.csv'}")

fig, ax = plt.subplots(figsize=(14, 12))
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm',
            center=0, square=True, linewidths=0.5,
            cbar_kws={'shrink': 0.8}, ax=ax, annot_kws={'size': 8})
ax.set_title('Feature Correlation Matrix', fontsize=14, fontweight='bold', pad=20)
plt.tight_layout()
plt.savefig(IMAGES_DIR / '09_correlation_matrix.png', dpi=150, bbox_inches='tight')
plt.show()
print(f"Saved: 09_correlation_matrix.png")

print("\nHighly correlated pairs (|r| > 0.9):")
found = False
for i in range(len(corr_matrix.columns)):
    for j in range(i+1, len(corr_matrix.columns)):
        val = corr_matrix.iloc[i, j]
        if abs(val) > 0.9:
            print(f"  {corr_matrix.columns[i]} vs {corr_matrix.columns[j]}: {val:.3f}")
            found = True
if not found:
    print("  None found above 0.9")

# %% [markdown]
# ## 14. Feature Statistics Summary

# %%
stats = df[corr_features].describe().T
stats['missing_pct'] = (df[corr_features].isnull().sum() / len(df) * 100).values
stats.to_csv(METRICS_DIR / 'feature_statistics.csv')
print(f"Saved: {METRICS_DIR / 'feature_statistics.csv'}")
print()
print(stats.to_string())

# %% [markdown]
# ## 15. Variant Disease Link Quality

# %%
if 'variant_disease_link_quality' in df.columns:
    print("Variant Disease Link Quality Distribution")
    link_dist = df['variant_disease_link_quality'].value_counts()
    print(link_dist.to_string())
    
    fig, ax = plt.subplots(figsize=(10, 6))
    colors = {'High_Quality': '#27ae60', 'Medium_Quality': '#f39c12',
              'Low_Quality': '#e67e22', 'No_Link': '#e74c3c'}
    bar_colors = [colors.get(x, '#95a5a6') for x in link_dist.index]
    
    bars = ax.bar(link_dist.index, link_dist.values, color=bar_colors, alpha=0.8, edgecolor='black')
    for bar, count in zip(bars, link_dist.values):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height(),
                f'{count:,}\n({count/total*100:.1f}%)',
                ha='center', va='bottom', fontsize=10, fontweight='bold')
    
    ax.set_xlabel('Link Quality', fontsize=11, fontweight='bold')
    ax.set_ylabel('Number of Variants', fontsize=11, fontweight='bold')
    ax.set_title('Variant Disease Link Quality Distribution', fontsize=12, fontweight='bold')
    ax.tick_params(axis='x', rotation=30)
    ax.grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(IMAGES_DIR / '10_variant_disease_link_quality.png', dpi=150, bbox_inches='tight')
    plt.show()
    print(f"Saved: 10_variant_disease_link_quality.png")

# %% [markdown]
# ## 16. Conservation Scores

# %%
if 'phylop_score' in df.columns and 'cadd_phred' in df.columns:
    fig, axes = plt.subplots(1, 2, figsize=(14, 6))
    
    phylop_data = df['phylop_score'].dropna()
    axes[0].hist(phylop_data, bins=50, color='darkorange', alpha=0.8, edgecolor='black')
    axes[0].axvline(2.7, color='red', linestyle='--', linewidth=2, label='Threshold 2.7')
    axes[0].set_xlabel('PhyloP Score', fontsize=11, fontweight='bold')
    axes[0].set_ylabel('Frequency', fontsize=11, fontweight='bold')
    axes[0].set_title('PhyloP Conservation Score Distribution', fontsize=12, fontweight='bold')
    axes[0].legend()
    axes[0].grid(alpha=0.3)
    
    cadd_data = df['cadd_phred'].dropna()
    axes[1].hist(cadd_data, bins=50, color='darkgreen', alpha=0.8, edgecolor='black')
    axes[1].axvline(20, color='red', linestyle='--', linewidth=2, label='Threshold 20')
    axes[1].set_xlabel('CADD Phred Score', fontsize=11, fontweight='bold')
    axes[1].set_ylabel('Frequency', fontsize=11, fontweight='bold')
    axes[1].set_title('CADD Score Distribution', fontsize=12, fontweight='bold')
    axes[1].legend()
    axes[1].grid(alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(IMAGES_DIR / '11_conservation_scores.png', dpi=150, bbox_inches='tight')
    plt.show()
    print(f"Saved: 11_conservation_scores.png")
    
    above_phylop = (df['phylop_score'] > 2.7).sum()
    above_cadd   = (df['cadd_phred'] > 20).sum()
    print(f"\nHighly conserved (PhyloP > 2.7) : {above_phylop:,} ({above_phylop/total*100:.1f}%)")
    print(f"Deleterious by CADD (> 20)       : {above_cadd:,}  ({above_cadd/total*100:.1f}%)")

# %% [markdown]
# ## 17. EDA Report

# %%
report_path = REPORTS_DIR / 'disease_eda_report.txt'

images_generated = sorted(IMAGES_DIR.glob('*.png'))

with open(report_path, 'w') as f:
    f.write("=" * 80 + "\n")
    f.write("DISEASE ML FEATURES - EDA REPORT\n")
    f.write("DNA Gene Mapping Project - ML Phase V5\n")
    f.write("=" * 80 + "\n\n")
    
    f.write("TABLE: gold.disease_ml_features\n")
    f.write(f"Sample rows  : {len(df):,} (10% of ~4.1M)\n")
    f.write(f"Columns      : {len(df.columns)}\n")
    f.write(f"Unique genes : {df['gene_name'].nunique():,}\n\n")
    
    f.write("TARGET VARIABLE\n")
    f.write("-" * 40 + "\n")
    f.write(f"Pathogenic : {pathogenic_count:,} ({pathogenic_count/total*100:.1f}%)\n")
    f.write(f"Benign     : {benign_count:,} ({benign_count/total*100:.1f}%)\n")
    f.write(f"VUS        : {vus_count:,} ({vus_count/total*100:.1f}%)\n")
    if pathogenic_count > 0 and benign_count > 0:
        f.write(f"Imbalance  : {imbalance_ratio:.2f}:1\n")
        f.write(f"SMOTE      : {'Recommended' if imbalance_ratio > 5 else 'Not required'}\n\n")
    
    f.write("DATABASE COVERAGE\n")
    f.write("-" * 40 + "\n")
    f.write(f"OMIM     : {omim_cov:,} ({omim_cov/total*100:.1f}%)\n")
    f.write(f"MONDO    : {mondo_cov:,} ({mondo_cov/total*100:.1f}%)\n")
    f.write(f"Orphanet : {orphanet_cov:,} ({orphanet_cov/total*100:.1f}%)\n")
    f.write(f"All three: {all_three:,}\n\n")
    
    f.write("MISSING VALUES\n")
    f.write("-" * 40 + "\n")
    f.write(f"Columns with missing data: {len(missing_with_nulls)}\n")
    if len(missing_with_nulls) > 0:
        for _, row in missing_with_nulls.head(10).iterrows():
            f.write(f"  {row['column']:<45} {row['missing_pct']:.1f}%\n")
    f.write("\n")
    
    f.write("VISUALIZATIONS GENERATED\n")
    f.write("-" * 40 + "\n")
    for img in images_generated:
        f.write(f"  {img.name}\n")
    f.write("\n")
    
    f.write("OUTPUT FILES\n")
    f.write("-" * 40 + "\n")
    f.write(f"  images/   : {len(images_generated)} PNG files\n")
    f.write(f"  reports/  : disease_eda_report.txt\n")
    f.write(f"  metrics/  : missing_values.csv, correlation_matrix.csv, feature_statistics.csv\n")
    f.write("\n")
    
    f.write("NEXT STEPS\n")
    f.write("-" * 40 + "\n")
    f.write("  1. Review class imbalance before training\n")
    f.write("  2. Remove leakage columns: clinical_significance_simple, disease_enriched\n")
    f.write("  3. Apply correlation filter (r > 0.95)\n")
    f.write("  4. Proceed to 02_clinical_ml_features_eda.ipynb\n")

print(f"Saved: {report_path}")
print()
print("=" * 60)
print("DISEASE ML FEATURES EDA COMPLETE")
print("=" * 60)
print(f"  Images   : {len(images_generated)}")
print(f"  Reports  : 1")
print(f"  Metrics  : 3 CSV files")
print(f"  Output   : {BASE_OUT}")
print()
print("Next: 02_clinical_ml_features_eda.ipynb")
